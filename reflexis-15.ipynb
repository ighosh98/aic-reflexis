# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas import datetime
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Bidirectional, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, K, Reshape, LSTM, CuDNNLSTM
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import *
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from keras.losses import *
from sklearn.preprocessing import LabelEncoder, minmax_scale, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from keras import backend as K
import sklearn
import itertools
import cv2
import scipy
import os
import csv
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# %matplotlib inline
import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['Store Attributes - Store Attributes.csv', 'BITS AIC 2019 - Reflexis Raw Dataset.csv']

# %%
df = pd.read_csv('../input/BITS AIC 2019 - Reflexis Raw Dataset.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df.head()
# Out:
#             STORE         ...          SYSTEM_SCHED_HOURS
# DATE                      ...
# 2016-01-31    203         ...                       20.50
# 2016-02-01    203         ...                       29.75
# 2016-02-02    203         ...                       25.50
# 2016-02-03    203         ...                       27.50
# 2016-02-04    203         ...                       27.25
#
# [5 rows x 6 columns]

# %%
df=df.dropna()
df.head()
# Out:
#             STORE         ...          SYSTEM_SCHED_HOURS
# DATE                      ...
# 2016-01-31    203         ...                       20.50
# 2016-02-01    203         ...                       29.75
# 2016-02-02    203         ...                       25.50
# 2016-02-03    203         ...                       27.50
# 2016-02-04    203         ...                       27.25
#
# [5 rows x 6 columns]

# %%
print('Max sales = ', df['SALES_ACTUAL'].max())
print('Number of records =', len(df))
# Out:
# Max sales =  113805.47
# Number of records = 121062

# %%
 #Note: Max profit ever made is the max profit it will ever make, Min possible sales made is the minimum it was ever mode(Since we don't have sufficient parameters)

# %%
df1 = df.groupby('STORE')
_temp = []
scalar = MinMaxScaler(feature_range=(-1,1))
for store_no, store_data in df1:
    data = df1.get_group(store_no).copy()
    #data['SALES_DELTA_NORM'] = minmax_scale(data['SALES_ACTUAL'], feature_range=(-1, 1))
    
    data['SALES_DELTA_NORM'] = scalar.fit_transform(data['SALES_ACTUAL'].values.reshape(-1,1))
    for i in data['SALES_DELTA_NORM'].values:
        _temp.append(i)
df['SALES_DELTA_NORM'] = _temp

df1 = df.groupby('STORE')
df
# Out:
#             STORE        ...         SALES_DELTA_NORM
# DATE                     ...
# 2016-01-31    203        ...                -0.578366
# 2016-02-01    203        ...                -0.888607
# 2016-02-02    203        ...                -0.811208
# 2016-02-03    203        ...                -0.801040
# 2016-02-04    203        ...                -0.863325
# 2016-02-05    203        ...                -0.895431
# 2016-02-06    203        ...                -0.600990
# 2016-02-07    203        ...                -0.586515
# 2016-02-08    203        ...                -0.961026
# 2016-02-09    203        ...                -0.799044
# 2016-02-10    203        ...                -0.740572
# 2016-02-11    203        ...                -0.728486
# 2016-02-12    203        ...                -0.690446
# 2016-02-13    203        ...                -0.490816
# 2016-02-14    203        ...                -0.763214
# 2016-02-15    203        ...                -0.659326
# 2016-02-16    203        ...                -0.792212
# 2016-02-17    203        ...                -0.742127
# 2016-02-18    203        ...                -0.830136
# 2016-02-19    203        ...                -0.683047
# 2016-02-20    203        ...                -0.485386
# 2016-02-21    203        ...                -0.686007
# 2016-02-22    203        ...                -0.873134
# 2016-02-23    203        ...                -0.767571
# 2016-02-24    203        ...                -0.850036
# 2016-02-25    203        ...                -0.842086
# 2016-02-26    203        ...                -0.693411
# 2016-02-27    203        ...                -0.217135
# 2016-02-28    203        ...                -0.718642
# 2016-02-29    203        ...                -0.821771
# ...           ...        ...                      ...
# 2018-01-26   7903        ...                -0.882518
# 2018-01-27   7903        ...                -0.703624
# 2018-01-28   7903        ...                -0.877236
# 2018-01-29   7903        ...                -0.928553
# 2018-01-30   7903        ...                -0.924463
# 2018-01-31   7903        ...                -0.945820
# 2018-02-01   7903        ...                -0.890925
# 2018-02-02   7903        ...                -0.860228
# 2018-02-03   7903        ...                -0.702491
# 2018-02-04   7903        ...                -0.799379
# 2018-02-05   7903        ...                -0.946781
# 2018-02-06   7903        ...                -0.918096
# 2018-02-07   7903        ...                -0.919150
# 2018-02-08   7903        ...                -0.903142
# 2018-02-09   7903        ...                -0.860087
# 2018-02-10   7903        ...                -0.600612
# 2018-02-11   7903        ...                -0.843186
# 2018-02-12   7903        ...                -0.893647
# 2018-02-13   7903        ...                -0.930971
# 2018-02-14   7903        ...                -0.929059
# 2018-02-15   7903        ...                -0.856726
# 2018-02-16   7903        ...                -0.667372
# 2018-02-17   7903        ...                -0.201602
# 2018-02-18   7903        ...                -0.636383
# 2018-02-19   7903        ...                -0.695475
# 2018-02-20   7903        ...                -0.915566
# 2018-02-21   7903        ...                -0.955041
# 2018-02-22   7903        ...                -0.882124
# 2018-02-23   7903        ...                -0.792662
# 2018-02-24   7903        ...                -0.513425
#
# [121062 rows x 7 columns]

# %%
class MetricsCheckpoint(Callback):
    """Callback that saves metrics after each epoch"""
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)
        
class MetricsCheckpoint(Callback):
    """Callback that saves metrics after each epoch"""
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

def plotKerasLearningCurve():
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['loss'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        #l = metrics[k]
        l = np.sqrt(scalar.inverse_transform(np.array(metrics[k]).reshape(-1,1)).ravel()).tolist()
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train')
        x = np.argmin(l)
        y = float(l[x])
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b')
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('Number of epochs')
    plt.ylabel('RMSE')
    
def plot_learning_curve(history):
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('./loss_curve.png')

# %%
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 

def f1(dfin, store_no, epochs):
#def f1(data, store_no, epochs):
    #predict sales given date, store number, system scheduled hours and manager scheduled hours
    while 1:
        data = dfin.get_group(store_no)
        batch_size = 8
        scalar.fit(data['SALES_ACTUAL'].values.reshape(-1,1))
        #batch_size = 256
        split_date = '2018-01-01'
        X_train, Y_train, X_test, Y_test = data[data.index < split_date][['STORE','MANAGER_SCHED_HOURS','SYSTEM_SCHED_HOURS']], data[data.index < split_date]['SALES_DELTA_NORM'], data[data.index> split_date][['STORE','MANAGER_SCHED_HOURS','SYSTEM_SCHED_HOURS']], data[data.index > split_date]['SALES_DELTA_NORM']
        #X_train, X_test, Y_train, Y_test = train_test_split(data[['STORE','MANAGER_SCHED_HOURS','SYSTEM_SCHED_HOURS']],data['SALES_ACTUAL'], shuffle=False)
        X_train = X_train.values.reshape(X_train.shape[0],1,X_train.shape[1])
        X_test = X_test.values.reshape(X_test.shape[0],1,X_test.shape[1])
        input_shape = (1,X_test.shape[2])
        num_classes = 1
        model = Sequential()
        model.add(Bidirectional(CuDNNLSTM(64, return_sequences=True, input_shape=input_shape)))
        model.add(Dropout(0.25))
        model.add(Bidirectional(CuDNNLSTM(64, return_sequences=True)))
        model.add(Dropout(0.25))
        model.add(Bidirectional(CuDNNLSTM(64)))
        model.add(Dropout(0.25))
        model.add(Dense(num_classes, activation='tanh'))
        model.compile(loss=root_mean_squared_error, optimizer = Adam(lr=0.01), metrics=[root_mean_squared_error])
        history = model.fit(X_train, Y_train.values, epochs = epochs, steps_per_epoch=int(len(X_train) / batch_size), validation_data=(X_test, Y_test.values), validation_steps=max(int(len(X_test)/batch_size),1), callbacks = [MetricsCheckpoint('logs')])
        #history = model.fit(X_train, Y_train.values, epochs = epochs, batch_size = batch_size, validation_data=(X_test, Y_test.values), callbacks = [MetricsCheckpoint('logs')])
        if np.inf not in history.history['loss']:
            score = model.evaluate(X_test, Y_test.values)
            plotKerasLearningCurve()
            plt.show()  
            plot_learning_curve(history)
            plt.show()
            return model
    
#def f2(data):
    #maximize sales, by adjusting sys_hrs and mgr_hrs for f1, output (sys_hrs,mgr_hrs)

# %%
lstm_model = f1(df1, 203, 50)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 701 samples, validate on 54 samples
# Epoch 1/50
# 87/87 [==============================] - 7s 81ms/step - loss: 0.1896 - root_mean_squared_error: 0.1896 - val_loss: 0.0780 - val_root_mean_squared_error: 0.0780
# Epoch 2/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1236 - root_mean_squared_error: 0.1236 - val_loss: 0.0722 - val_root_mean_squared_error: 0.0722
# Epoch 3/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1184 - root_mean_squared_error: 0.1184 - val_loss: 0.0992 - val_root_mean_squared_error: 0.0992
# Epoch 4/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1159 - root_mean_squared_error: 0.1159 - val_loss: 0.0955 - val_root_mean_squared_error: 0.0955
# Epoch 5/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1146 - root_mean_squared_error: 0.1146 - val_loss: 0.0868 - val_root_mean_squared_error: 0.0868
# Epoch 6/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1148 - root_mean_squared_error: 0.1148 - val_loss: 0.0892 - val_root_mean_squared_error: 0.0892
# Epoch 7/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1141 - root_mean_squared_error: 0.1141 - val_loss: 0.0930 - val_root_mean_squared_error: 0.0930
# Epoch 8/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1136 - root_mean_squared_error: 0.1136 - val_loss: 0.0953 - val_root_mean_squared_error: 0.0953
# Epoch 9/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1137 - root_mean_squared_error: 0.1137 - val_loss: 0.0919 - val_root_mean_squared_error: 0.0919
# Epoch 10/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1130 - root_mean_squared_error: 0.1130 - val_loss: 0.0872 - val_root_mean_squared_error: 0.0872
# Epoch 11/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1125 - root_mean_squared_error: 0.1125 - val_loss: 0.0924 - val_root_mean_squared_error: 0.0924
# Epoch 12/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1126 - root_mean_squared_error: 0.1126 - val_loss: 0.0884 - val_root_mean_squared_error: 0.0884
# Epoch 13/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1120 - root_mean_squared_error: 0.1120 - val_loss: 0.0942 - val_root_mean_squared_error: 0.0942
# Epoch 14/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1115 - root_mean_squared_error: 0.1115 - val_loss: 0.0954 - val_root_mean_squared_error: 0.0954
# Epoch 15/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1110 - root_mean_squared_error: 0.1110 - val_loss: 0.0892 - val_root_mean_squared_error: 0.0892
# Epoch 16/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1116 - root_mean_squared_error: 0.1116 - val_loss: 0.0864 - val_root_mean_squared_error: 0.0864
# Epoch 17/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1117 - root_mean_squared_error: 0.1117 - val_loss: 0.0890 - val_root_mean_squared_error: 0.0890
# Epoch 18/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.0918 - val_root_mean_squared_error: 0.0918
# Epoch 19/50
# 87/87 [==============================] - 1s 10ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.0914 - val_root_mean_squared_error: 0.0914
# Epoch 20/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1111 - root_mean_squared_error: 0.1111 - val_loss: 0.0882 - val_root_mean_squared_error: 0.0882
# Epoch 21/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1104 - root_mean_squared_error: 0.1104 - val_loss: 0.0914 - val_root_mean_squared_error: 0.0914
# Epoch 22/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1102 - root_mean_squared_error: 0.1102 - val_loss: 0.0882 - val_root_mean_squared_error: 0.0882
# Epoch 23/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1105 - root_mean_squared_error: 0.1105 - val_loss: 0.0854 - val_root_mean_squared_error: 0.0854
# Epoch 24/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1110 - root_mean_squared_error: 0.1110 - val_loss: 0.0873 - val_root_mean_squared_error: 0.0873
# Epoch 25/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1103 - root_mean_squared_error: 0.1103 - val_loss: 0.0918 - val_root_mean_squared_error: 0.0918
# Epoch 26/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1098 - root_mean_squared_error: 0.1098 - val_loss: 0.0998 - val_root_mean_squared_error: 0.0998
# Epoch 27/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.0897 - val_root_mean_squared_error: 0.0897
# Epoch 28/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1098 - root_mean_squared_error: 0.1098 - val_loss: 0.0918 - val_root_mean_squared_error: 0.0918
# Epoch 29/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1103 - root_mean_squared_error: 0.1103 - val_loss: 0.0899 - val_root_mean_squared_error: 0.0899
# Epoch 30/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1103 - root_mean_squared_error: 0.1103 - val_loss: 0.0982 - val_root_mean_squared_error: 0.0982
# Epoch 31/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1103 - root_mean_squared_error: 0.1103 - val_loss: 0.0952 - val_root_mean_squared_error: 0.0952
# Epoch 32/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1099 - root_mean_squared_error: 0.1099 - val_loss: 0.0871 - val_root_mean_squared_error: 0.0871
# Epoch 33/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1105 - root_mean_squared_error: 0.1105 - val_loss: 0.0909 - val_root_mean_squared_error: 0.0909
# Epoch 34/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1103 - root_mean_squared_error: 0.1103 - val_loss: 0.0893 - val_root_mean_squared_error: 0.0893
# Epoch 35/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.0913 - val_root_mean_squared_error: 0.0913
# Epoch 36/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.0893 - val_root_mean_squared_error: 0.0893
# Epoch 37/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1094 - root_mean_squared_error: 0.1094 - val_loss: 0.0945 - val_root_mean_squared_error: 0.0945
# Epoch 38/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1101 - root_mean_squared_error: 0.1101 - val_loss: 0.0887 - val_root_mean_squared_error: 0.0887
# Epoch 39/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1102 - root_mean_squared_error: 0.1102 - val_loss: 0.1001 - val_root_mean_squared_error: 0.1001
# Epoch 40/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.0866 - val_root_mean_squared_error: 0.0866
# Epoch 41/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.0922 - val_root_mean_squared_error: 0.0922
# Epoch 42/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1094 - root_mean_squared_error: 0.1094 - val_loss: 0.0868 - val_root_mean_squared_error: 0.0868
# Epoch 43/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1097 - root_mean_squared_error: 0.1097 - val_loss: 0.0932 - val_root_mean_squared_error: 0.0932
# Epoch 44/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1094 - root_mean_squared_error: 0.1094 - val_loss: 0.0917 - val_root_mean_squared_error: 0.0917
# Epoch 45/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1104 - root_mean_squared_error: 0.1104 - val_loss: 0.0900 - val_root_mean_squared_error: 0.0900
# Epoch 46/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1098 - root_mean_squared_error: 0.1098 - val_loss: 0.0874 - val_root_mean_squared_error: 0.0874
# Epoch 47/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1102 - root_mean_squared_error: 0.1102 - val_loss: 0.0896 - val_root_mean_squared_error: 0.0896
# Epoch 48/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.0924 - val_root_mean_squared_error: 0.0924
# Epoch 49/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1093 - root_mean_squared_error: 0.1093 - val_loss: 0.0914 - val_root_mean_squared_error: 0.0914
# Epoch 50/50
# 87/87 [==============================] - 1s 9ms/step - loss: 0.1095 - root_mean_squared_error: 0.1095 - val_loss: 0.0915 - val_root_mean_squared_error: 0.0915
# 54/54 [==============================] - 0s 100us/step

# %%
#General scheme for feature visaulization is to iterate over all possible inputs
store_no = 203
ls1=[]
ls2=[]
dfstore = df1.get_group(store_no)
scalar.fit(dfstore['SALES_ACTUAL'].values.reshape(-1,1))
wpd = 12
for i in range(wpd*7*4+1):
    x_in = np.array([[store_no, float(i)/4.0, float(i)/4.0]])
    x_in = x_in.reshape(x_in.shape[0], 1, x_in.shape[1])
    ls1.append(scalar.inverse_transform(lstm_model.predict(x_in)).tolist()[0][0])

for j in range(wpd*7*4+1):
    x_in = np.array([[store_no, float(j)/4.0, float(ls1.index(max(ls1)))/4.0]])
    x_in = x_in.reshape(x_in.shape[0], 1, x_in.shape[1])
    ls2.append(scalar.inverse_transform(lstm_model.predict(x_in)).tolist()[0][0])
xrange = np.arange(0,wpd*7+0.25,0.25)

# %%
plt.figure(figsize=(24,8))
plt.subplot(1,2,1)
plt.plot(xrange, ls1)
plt.xlabel('System Hours')
plt.ylabel('Profits')
x = np.argmax(ls1)
y = ls1[x]
plt.scatter(x/4,y, lw=0, alpha=0.25, s=100, c='b')
plt.text(x/4, y, 'Max profit at\n{} = {:.4f}'.format(x/4,y), size='15', color='b')
plt.subplot(1,2,2)
plt.plot(xrange, ls2)
plt.xlabel('Manager Hours')
plt.ylabel('Profits')
x = np.argmax(ls2)
y = ls2[x]
plt.scatter(x/4,y, lw=0, alpha=0.25, s=100, c='b')
plt.text(x/4, y, 'Max profit at\n{} = {:.4f}'.format(x/4,y), size='15', color='b')
plt.show()
