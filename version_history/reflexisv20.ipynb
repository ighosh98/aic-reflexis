# %% [markdown]
# <h1>Predicting Ideal System Scheduled Hours to Maximize Sales</h1>
# <h2>AIC Reflexis Systems, Apogee 2019</h2>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from pandas import datetime
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation, Flatten, Bidirectional, Conv2D, MaxPooling2D, Lambda, MaxPool2D, BatchNormalization, Input, concatenate, K, Reshape, LSTM, CuDNNLSTM
from keras.utils import np_utils
from keras.optimizers import *
from keras.callbacks import Callback, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
from keras.utils.np_utils import to_categorical
from keras.losses import *
from sklearn.preprocessing import LabelEncoder, minmax_scale, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from keras import backend as K
import sklearn
import os
import matplotlib.pyplot as plt
# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory
# %matplotlib inline
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# Using TensorFlow backend.
# ['Store Attributes - Store Attributes.csv', 'BITS AIC 2019 - Reflexis Raw Dataset.csv']

# %% [markdown]
# <h2>__Import Dataset__</h2>
# We first import the dataset. If using on a local machine or a fork, please change the file location in pd.read_csv().

# %%
#Import Dataset
df = pd.read_csv('../input/BITS AIC 2019 - Reflexis Raw Dataset.csv')
df['DATE'] = pd.to_datetime(df['DATE']) #Convert date strings to datetime format
df = df.set_index('DATE') #Index by Date
df.head()
# Out:
#             STORE         ...          SYSTEM_SCHED_HOURS
# DATE                      ...
# 2016-01-31    203         ...                       20.50
# 2016-02-01    203         ...                       29.75
# 2016-02-02    203         ...                       25.50
# 2016-02-03    203         ...                       27.50
# 2016-02-04    203         ...                       27.25
#
# [5 rows x 6 columns]

# %% [markdown]
# <h1>Clean Dataset</h1>
# We remove rows with missing values, to make sure that we are making predictions only for present values.

# %%
#Cleaning Dataset
df=df.dropna() #Drop missing values
df.head()
# Out:
#             STORE         ...          SYSTEM_SCHED_HOURS
# DATE                      ...
# 2016-01-31    203         ...                       20.50
# 2016-02-01    203         ...                       29.75
# 2016-02-02    203         ...                       25.50
# 2016-02-03    203         ...                       27.50
# 2016-02-04    203         ...                       27.25
#
# [5 rows x 6 columns]

# %%
#Exploratory Data Analysis
print('Max sales = ', df['SALES_ACTUAL'].max()) 
print('Number of records =', len(df))
# Out:
# Max sales =  113805.47
# Number of records = 121062

# %%
 #Note: Max profit ever made is the max profit it will ever make, Min possible sales made is the minimum it was ever mode(Since we don't have sufficient parameters)

# %%
#Scaling Actual Sales values
df1 = df.groupby('STORE') #Group data by store
_temp = []
scalar = MinMaxScaler(feature_range=(-1,1))
for store_no, store_data in df1:
    data = df1.get_group(store_no).copy()    
    data['SALES_NORM'] = scalar.fit_transform(data['SALES_ACTUAL'].values.reshape(-1,1)) #Scaled sales between (-1,1)
    for i in data['SALES_NORM'].values:
        _temp.append(i)
df['SALES_NORM'] = _temp 
df1 = df.groupby('STORE') #Store grouped dataset separately 
df
# Out:
#             STORE  TRAFFIC_ACTUAL     ...      SYSTEM_SCHED_HOURS  SALES_NORM
# DATE                                  ...
# 2016-01-31    203             180     ...                   20.50   -0.578366
# 2016-02-01    203              49     ...                   29.75   -0.888607
# 2016-02-02    203              85     ...                   25.50   -0.811208
# 2016-02-03    203              84     ...                   27.50   -0.801040
# 2016-02-04    203              69     ...                   27.25   -0.863325
# 2016-02-05    203              53     ...                   31.50   -0.895431
# 2016-02-06    203             248     ...                   39.75   -0.600990
# 2016-02-07    203             147     ...                   21.50   -0.586515
# 2016-02-08    203               8     ...                   23.25   -0.961026
# 2016-02-09    203              78     ...                   23.50   -0.799044
# 2016-02-10    203              75     ...                   24.50   -0.740572
# 2016-02-11    203              99     ...                   24.75   -0.728486
# 2016-02-12    203             126     ...                   28.75   -0.690446
# 2016-02-13    203             338     ...                   39.75   -0.490816
# 2016-02-14    203             224     ...                   25.50   -0.763214
# 2016-02-15    203             264     ...                   35.50   -0.659326
# 2016-02-16    203             116     ...                   23.00   -0.792212
# 2016-02-17    203             128     ...                   32.50   -0.742127
# 2016-02-18    203             154     ...                   20.00   -0.830136
# 2016-02-19    203             200     ...                   31.75   -0.683047
# 2016-02-20    203             281     ...                   35.25   -0.485386
# 2016-02-21    203             161     ...                   25.50   -0.686007
# 2016-02-22    203              64     ...                   23.25   -0.873134
# 2016-02-23    203              60     ...                   23.50   -0.767571
# 2016-02-24    203              70     ...                   24.50   -0.850036
# 2016-02-25    203              59     ...                   24.75   -0.842086
# 2016-02-26    203             129     ...                   23.75   -0.693411
# 2016-02-27    203             344     ...                   41.25   -0.217135
# 2016-02-28    203             151     ...                   20.50   -0.718642
# 2016-02-29    203              77     ...                   23.25   -0.821771
# ...           ...             ...     ...                     ...         ...
# 2018-01-26   7903             311     ...                   28.50   -0.882518
# 2018-01-27   7903             956     ...                   72.50   -0.703624
# 2018-01-28   7903             503     ...                   21.00   -0.877236
# 2018-01-29   7903             217     ...                   23.00   -0.928553
# 2018-01-30   7903             169     ...                   22.00   -0.924463
# 2018-01-31   7903             157     ...                   23.00   -0.945820
# 2018-02-01   7903             215     ...                   22.00   -0.890925
# 2018-02-02   7903             311     ...                   26.50   -0.860228
# 2018-02-03   7903             888     ...                   45.00   -0.702491
# 2018-02-04   7903             385     ...                   34.00   -0.799379
# 2018-02-05   7903             146     ...                   29.50   -0.946781
# 2018-02-06   7903             154     ...                   28.25   -0.918096
# 2018-02-07   7903             180     ...                   24.75   -0.919150
# 2018-02-08   7903             201     ...                   28.25   -0.903142
# 2018-02-09   7903             319     ...                   30.75   -0.860087
# 2018-02-10   7903            1092     ...                   71.50   -0.600612
# 2018-02-11   7903             466     ...                   36.75   -0.843186
# 2018-02-12   7903             195     ...                   28.25   -0.893647
# 2018-02-13   7903             163     ...                   28.25   -0.930971
# 2018-02-14   7903             163     ...                   31.50   -0.929059
# 2018-02-15   7903             226     ...                   30.50   -0.856726
# 2018-02-16   7903             487     ...                   39.50   -0.667372
# 2018-02-17   7903            1418     ...                   61.75   -0.201602
# 2018-02-18   7903             976     ...                   35.75   -0.636383
# 2018-02-19   7903             645     ...                   20.75   -0.695475
# 2018-02-20   7903             151     ...                   23.25   -0.915566
# 2018-02-21   7903             162     ...                   24.50   -0.955041
# 2018-02-22   7903             265     ...                   20.75   -0.882124
# 2018-02-23   7903             472     ...                   33.25   -0.792662
# 2018-02-24   7903            1398     ...                   56.25   -0.513425
#
# [121062 rows x 7 columns]

# %%
# Helper Functions for Graph Generation
class MetricsCheckpoint(Callback):
    # Callback that saves metrics after each epoch
    def __init__(self, savepath):
        super(MetricsCheckpoint, self).__init__()
        self.savepath = savepath
        self.history = {}
        
    def on_epoch_end(self, epoch, logs=None):
        for k, v in logs.items():
            self.history.setdefault(k, []).append(v)
        np.save(self.savepath, self.history)

#Plots RMSE
def plotKerasLearningCurve():
    plt.figure(figsize=(10,5))
    metrics = np.load('logs.npy')[()]
    filt = ['loss'] # try to add 'loss' to see the loss learning curve
    for k in filter(lambda x : np.any([kk in x for kk in filt]), metrics.keys()):
        l = np.sqrt(scalar.inverse_transform(np.array(metrics[k]).reshape(-1,1)).ravel()).tolist() #Restructuring data
        plt.plot(l, c= 'r' if 'val' not in k else 'b', label='val' if 'val' in k else 'train') #line plot of of metrics or loss
        x = np.argmin(l)
        y = float(l[x])
        plt.scatter(x,y, lw=0, alpha=0.25, s=100, c='r' if 'val' not in k else 'b') #Scatter plot of maxima
        plt.text(x, y, '{} = {:.4f}'.format(x,y), size='15', color= 'r' if 'val' not in k else 'b')   
    plt.legend(loc=4)
    plt.axis([0, None, None, None]);
    plt.grid()
    plt.xlabel('Number of epochs')
    plt.ylabel('RMSE')
    plt.savefig('./RMSE_curve.png')

#Plot Loss    
def plot_learning_curve(history):
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.savefig('./loss_curve.png')

# %%
#RMSE Calculation function
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 

#Neural Network
def f1(dfin, store_no, epochs):
    #predict sales given date, store number, system scheduled hours and manager scheduled hours
    while True:
        data = dfin.get_group(store_no)
        batch_size = 8
        scalar.fit(data['SALES_ACTUAL'].values.reshape(-1,1))
        split_date = '2018-02-01'
        X_train, Y_train, X_test, Y_test = data[data.index < split_date][['STORE','MANAGER_SCHED_HOURS','SYSTEM_SCHED_HOURS']], data[data.index < split_date]['SALES_NORM'], data[data.index>= split_date][['STORE','MANAGER_SCHED_HOURS','SYSTEM_SCHED_HOURS']], data[data.index >= split_date]['SALES_NORM']
        X_train = X_train.values.reshape(X_train.shape[0],1,X_train.shape[1])
        X_test = X_test.values.reshape(X_test.shape[0],1,X_test.shape[1])
        input_shape = (1,X_test.shape[2])
        num_classes = 1
        model = Sequential()
        model.add(Bidirectional(CuDNNLSTM(64, return_sequences=True, input_shape=input_shape)))
        model.add(Dropout(0.25))
        model.add(Bidirectional(CuDNNLSTM(64, return_sequences=True)))
        model.add(Dropout(0.25))
        model.add(Bidirectional(CuDNNLSTM(64)))
        model.add(Dropout(0.25))
        model.add(Dense(num_classes, activation='tanh'))
        model.compile(loss=root_mean_squared_error, optimizer = Adam(lr=0.01), metrics=[root_mean_squared_error])
        history = model.fit(X_train, Y_train.values, epochs = epochs, steps_per_epoch=int(len(X_train) / batch_size), validation_data=(X_test, Y_test.values), validation_steps=max(int(len(X_test)/batch_size),1), callbacks = [MetricsCheckpoint('logs')])
        if np.inf not in history.history['loss']:
            score = model.evaluate(X_test, Y_test.values)
            plotKerasLearningCurve()
            plt.show()  
            plot_learning_curve(history)
            plt.show()
            return model

# %%
#Generating model for store 203
lstm_model = f1(df1, 203, 50)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 732 samples, validate on 24 samples
# Epoch 1/50
# 91/91 [==============================] - 6s 62ms/step - loss: 0.1448 - root_mean_squared_error: 0.1448 - val_loss: 0.0860 - val_root_mean_squared_error: 0.0860
# Epoch 2/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1178 - root_mean_squared_error: 0.1178 - val_loss: 0.1049 - val_root_mean_squared_error: 0.1049
# Epoch 3/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1154 - root_mean_squared_error: 0.1154 - val_loss: 0.1200 - val_root_mean_squared_error: 0.1200
# Epoch 4/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1148 - root_mean_squared_error: 0.1148 - val_loss: 0.1093 - val_root_mean_squared_error: 0.1093
# Epoch 5/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1139 - root_mean_squared_error: 0.1139 - val_loss: 0.1002 - val_root_mean_squared_error: 0.1002
# Epoch 6/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1135 - root_mean_squared_error: 0.1135 - val_loss: 0.1052 - val_root_mean_squared_error: 0.1052
# Epoch 7/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1129 - root_mean_squared_error: 0.1129 - val_loss: 0.1101 - val_root_mean_squared_error: 0.1101
# Epoch 8/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1130 - root_mean_squared_error: 0.1130 - val_loss: 0.1112 - val_root_mean_squared_error: 0.1112
# Epoch 9/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1127 - root_mean_squared_error: 0.1127 - val_loss: 0.1191 - val_root_mean_squared_error: 0.1191
# Epoch 10/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1125 - root_mean_squared_error: 0.1125 - val_loss: 0.1205 - val_root_mean_squared_error: 0.1205
# Epoch 11/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1119 - root_mean_squared_error: 0.1119 - val_loss: 0.1109 - val_root_mean_squared_error: 0.1109
# Epoch 12/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1121 - root_mean_squared_error: 0.1121 - val_loss: 0.1219 - val_root_mean_squared_error: 0.1219
# Epoch 13/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1116 - root_mean_squared_error: 0.1116 - val_loss: 0.1057 - val_root_mean_squared_error: 0.1057
# Epoch 14/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1112 - root_mean_squared_error: 0.1112 - val_loss: 0.1253 - val_root_mean_squared_error: 0.1253
# Epoch 15/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1117 - root_mean_squared_error: 0.1117 - val_loss: 0.1262 - val_root_mean_squared_error: 0.1262
# Epoch 16/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1111 - root_mean_squared_error: 0.1111 - val_loss: 0.0922 - val_root_mean_squared_error: 0.0922
# Epoch 17/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1115 - root_mean_squared_error: 0.1115 - val_loss: 0.1279 - val_root_mean_squared_error: 0.1279
# Epoch 18/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1114 - root_mean_squared_error: 0.1114 - val_loss: 0.1282 - val_root_mean_squared_error: 0.1282
# Epoch 19/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1117 - root_mean_squared_error: 0.1117 - val_loss: 0.0970 - val_root_mean_squared_error: 0.0970
# Epoch 20/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1115 - root_mean_squared_error: 0.1115 - val_loss: 0.1173 - val_root_mean_squared_error: 0.1173
# Epoch 21/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1110 - root_mean_squared_error: 0.1110 - val_loss: 0.1170 - val_root_mean_squared_error: 0.1170
# Epoch 22/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1108 - root_mean_squared_error: 0.1108 - val_loss: 0.1241 - val_root_mean_squared_error: 0.1241
# Epoch 23/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1099 - root_mean_squared_error: 0.1099 - val_loss: 0.1235 - val_root_mean_squared_error: 0.1235
# Epoch 24/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.1246 - val_root_mean_squared_error: 0.1246
# Epoch 25/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.1204 - val_root_mean_squared_error: 0.1204
# Epoch 26/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1105 - root_mean_squared_error: 0.1105 - val_loss: 0.1197 - val_root_mean_squared_error: 0.1197
# Epoch 27/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.1281 - val_root_mean_squared_error: 0.1281
# Epoch 28/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1100 - root_mean_squared_error: 0.1100 - val_loss: 0.1216 - val_root_mean_squared_error: 0.1216
# Epoch 29/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.1338 - val_root_mean_squared_error: 0.1338
# Epoch 30/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1115 - root_mean_squared_error: 0.1115 - val_loss: 0.1237 - val_root_mean_squared_error: 0.1237
# Epoch 31/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1102 - root_mean_squared_error: 0.1102 - val_loss: 0.1215 - val_root_mean_squared_error: 0.1215
# Epoch 32/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1112 - root_mean_squared_error: 0.1112 - val_loss: 0.1189 - val_root_mean_squared_error: 0.1189
# Epoch 33/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1097 - root_mean_squared_error: 0.1097 - val_loss: 0.1237 - val_root_mean_squared_error: 0.1237
# Epoch 34/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1096 - root_mean_squared_error: 0.1096 - val_loss: 0.1167 - val_root_mean_squared_error: 0.1167
# Epoch 35/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1099 - root_mean_squared_error: 0.1099 - val_loss: 0.1019 - val_root_mean_squared_error: 0.1019
# Epoch 36/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1106 - root_mean_squared_error: 0.1106 - val_loss: 0.1288 - val_root_mean_squared_error: 0.1288
# Epoch 37/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1114 - root_mean_squared_error: 0.1114 - val_loss: 0.0953 - val_root_mean_squared_error: 0.0953
# Epoch 38/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1098 - root_mean_squared_error: 0.1098 - val_loss: 0.1299 - val_root_mean_squared_error: 0.1299
# Epoch 39/50
# 91/91 [==============================] - 1s 9ms/step - loss: 0.1096 - root_mean_squared_error: 0.1096 - val_loss: 0.1304 - val_root_mean_squared_error: 0.1304
# Epoch 40/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1097 - root_mean_squared_error: 0.1097 - val_loss: 0.1191 - val_root_mean_squared_error: 0.1191
# Epoch 41/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1096 - root_mean_squared_error: 0.1096 - val_loss: 0.1193 - val_root_mean_squared_error: 0.1193
# Epoch 42/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1091 - root_mean_squared_error: 0.1091 - val_loss: 0.0911 - val_root_mean_squared_error: 0.0911
# Epoch 43/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1101 - root_mean_squared_error: 0.1101 - val_loss: 0.1245 - val_root_mean_squared_error: 0.1245
# Epoch 44/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1095 - root_mean_squared_error: 0.1095 - val_loss: 0.1259 - val_root_mean_squared_error: 0.1259
# Epoch 45/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1091 - root_mean_squared_error: 0.1091 - val_loss: 0.1201 - val_root_mean_squared_error: 0.1201
# Epoch 46/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1085 - root_mean_squared_error: 0.1085 - val_loss: 0.1191 - val_root_mean_squared_error: 0.1191
# Epoch 47/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1084 - root_mean_squared_error: 0.1084 - val_loss: 0.1250 - val_root_mean_squared_error: 0.1250
# Epoch 48/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1091 - root_mean_squared_error: 0.1091 - val_loss: 0.1232 - val_root_mean_squared_error: 0.1232
# Epoch 49/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1107 - root_mean_squared_error: 0.1107 - val_loss: 0.1201 - val_root_mean_squared_error: 0.1201
# Epoch 50/50
# 91/91 [==============================] - 1s 10ms/step - loss: 0.1088 - root_mean_squared_error: 0.1088 - val_loss: 0.1261 - val_root_mean_squared_error: 0.1261
# 24/24 [==============================] - 0s 115us/step

# %%
#General scheme for feature visaulization is to iterate over all possible inputs
store_no = 203
ls1=[]
ls2=[]
dfstore = df1.get_group(store_no)
scalar.fit(dfstore['SALES_ACTUAL'].values.reshape(-1,1))
wpd = 12
for i in range(wpd*7*4+1):
    x_in = np.array([[store_no, float(i)/4.0, float(i)/4.0]])
    x_in = x_in.reshape(x_in.shape[0], 1, x_in.shape[1])
    ls1.append(scalar.inverse_transform(lstm_model.predict(x_in)).tolist()[0][0])

for j in range(wpd*7*4+1):
    x_in = np.array([[store_no, float(j)/4.0, float(ls1.index(max(ls1)))/4.0]])
    x_in = x_in.reshape(x_in.shape[0], 1, x_in.shape[1])
    ls2.append(scalar.inverse_transform(lstm_model.predict(x_in)).tolist()[0][0])
xrange = np.arange(0,wpd*7+0.25,0.25)

# %%
#Plot predicted values of sales 
plt.figure(figsize = (24,6))
plt.subplot(1,2,1)
plt.plot(xrange, ls1)
plt.xlabel('System Hours')
plt.ylabel('Profits')
x = np.argmax(ls1)
y = ls1[x]
plt.scatter(x/4, y, lw = 0, alpha = 0.25, s = 100, c = 'b')
plt.text( x/4, y, 'Max profit at\n{} = {:.4f}'.format(x/4,y), size='15', color='b')
plt.subplot(1,2,2)
plt.plot(xrange, ls2)
plt.xlabel('Manager Hours')
plt.ylabel('Profits')
x = np.argmax(ls2)
y = ls2[x]
plt.scatter(x/4,y, lw=0, alpha=0.25, s=100, c='b')
plt.text(x/4, y, 'Max profit at\n{} = {:.4f}'.format(x/4,y), size='15', color='b')
plt.show()
plt.savefig('./optimum_hours.png')
